# %%
import pandas as pd
import matplotlib.pyplot as plt
clust_152_returns = pd.read_csv('mkt_returns_clust_152.csv')
clust_152_returns.index = clust_152_returns.iloc[:,0]
clust_152_returns = clust_152_returns.iloc[:,1:]
clust_152_returns.tail()
# Out:
#             2018-06-25 00:00:00  ...  Cluster 152
# Unnamed: 0                       ...
# AF.PA                 -0.034268  ...           56
# ENGI.PA               -0.015867  ...           28
# ENX.PA                -0.013711  ...           91
# SGO.PA                -0.019103  ...           20
# TTE.PA                -0.015434  ...           28
#
# [5 rows x 1141 columns]

# %%
clust_152_returns['Cluster 152'].value_counts()
# Out:
# 63     28
# 28     21
# 91     14
# 82      9
# 20      8
#        ..
# 45      1
# 44      1
# 43      1
# 42      1
# 141     1
# Name: Cluster 152, Length: 142, dtype: int64

# %%
grp_63_ret = clust_152_returns[clust_152_returns['Cluster 152']==7].iloc[:,-366:-1].T

# %%
plt.plot(grp_63_ret.cumsum())
