# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import date
from dateutil.relativedelta import relativedelta
from fin_ratios import annual_risk_measures, range_80
from tqdm import tqdm

clust_162 = pd.read_pickle('clust_162.pickle')
returns = pd.read_pickle('returns.pickle')

date_2y_ago = pd.to_datetime(date.today() - relativedelta(years=2))
returns_2y = returns[returns.index > date_2y_ago]

# %%
def ratios_summary(ind):
    empty = pd.DataFrame()
    stock_name = returns_2y.iloc[:,ind].name
    annual_measures = annual_risk_measures(empty, returns_2y.iloc[:,ind]).dropna()
    annual_sortino_summary = pd.DataFrame([range_80(annual_measures, 'Sortino'), range_80(annual_measures, 'Beta'), range_80(annual_measures, 'CVar')], columns = ['10th centile','90th centile'])
    annual_sortino_summary.index = ['Sortino','Beta', 'CVar']
    #plt.plot(returns_2y.iloc[:,ind].cumsum())
    return stock_name, annual_sortino_summary

# %%
def shortlist(min_sortino, min_cvar):
    shortlist = pd.Series()
    for i in tqdm(range(returns_2y.shape[1])):
        try:
            name, data = ratios_summary(i)
            if (data.iloc[0,0] > min_sortino) & (data.iloc[2,0] > min_cvar):
                shortlist = shortlist.append(pd.Series(name))
        except:
            None
    return shortlist

# %%
from scipy.stats.mstats import winsorize

def winsorize_col(s):
    return winsorize(s, limits=[0.005,0.005])

returns_2y_win = returns_2y.apply(winsorize_col, axis=0).T

# %%
mettre ratio P/E

# %%
ou alors diviser en deux catégories, une pour short principalement et une pour long principalement

# %%
long_shortlist = shortlist(-0.5, -0.10)
# Out:
# <ipython-input-62-8dfeb28f5977>:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   shortlist = pd.Series()
# 100%|██████████| 249/249 [01:03<00:00,  3.92it/s]

# %%
long_shortlist = shortlist(-0.3, -0.05)
# Out:
# <ipython-input-62-8dfeb28f5977>:2: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   shortlist = pd.Series()
# 100%|██████████| 249/249 [01:03<00:00,  3.89it/s]

# %%
long_shortlist_returns = returns_2y_win[returns_2y_win.index.isin(long_shortlist)]

# %%
plt.plot(long_shortlist_returns.T.cumsum())
# Out:
# [<matplotlib.lines.Line2D at 0x1f64b1d9f10>,
#  <matplotlib.lines.Line2D at 0x1f64b220a60>,
#  <matplotlib.lines.Line2D at 0x1f64b2209a0>,
#  <matplotlib.lines.Line2D at 0x1f64b2208e0>,
#  <matplotlib.lines.Line2D at 0x1f64b220af0>,
#  <matplotlib.lines.Line2D at 0x1f64b220bb0>,
#  <matplotlib.lines.Line2D at 0x1f64b220c70>,
#  <matplotlib.lines.Line2D at 0x1f64b220d30>,
#  <matplotlib.lines.Line2D at 0x1f64b220df0>,
#  <matplotlib.lines.Line2D at 0x1f64b220eb0>,
#  <matplotlib.lines.Line2D at 0x1f64b1ff190>,
#  <matplotlib.lines.Line2D at 0x1f64b227040>,
#  <matplotlib.lines.Line2D at 0x1f64b227100>,
#  <matplotlib.lines.Line2D at 0x1f64b2271c0>,
#  <matplotlib.lines.Line2D at 0x1f64b227280>,
#  <matplotlib.lines.Line2D at 0x1f64b227340>,
#  <matplotlib.lines.Line2D at 0x1f64b227400>,
#  <matplotlib.lines.Line2D at 0x1f64b2274c0>,
#  <matplotlib.lines.Line2D at 0x1f64b227580>,
#  <matplotlib.lines.Line2D at 0x1f64b227640>,
#  <matplotlib.lines.Line2D at 0x1f64b227700>,
#  <matplotlib.lines.Line2D at 0x1f64b2277c0>,
#  <matplotlib.lines.Line2D at 0x1f64b227880>,
#  <matplotlib.lines.Line2D at 0x1f64b227940>,
#  <matplotlib.lines.Line2D at 0x1f64b227a00>,
#  <matplotlib.lines.Line2D at 0x1f64b227ac0>,
#  <matplotlib.lines.Line2D at 0x1f64b227b80>,
#  <matplotlib.lines.Line2D at 0x1f64b227c40>,
#  <matplotlib.lines.Line2D at 0x1f64b227d00>,
#  <matplotlib.lines.Line2D at 0x1f64b227dc0>,
#  <matplotlib.lines.Line2D at 0x1f64b227e80>,
#  <matplotlib.lines.Line2D at 0x1f64b227f40>,
#  <matplotlib.lines.Line2D at 0x1f64b22e040>,
#  <matplotlib.lines.Line2D at 0x1f64b22e100>,
#  <matplotlib.lines.Line2D at 0x1f64b22e1c0>,
#  <matplotlib.lines.Line2D at 0x1f64b22e280>,
#  <matplotlib.lines.Line2D at 0x1f64b22e340>]

# %%
ratios_summary(1)
# Out:
# Traceback (most recent call last):
#
#   File "<ipython-input-1-bb5760fd841d>", line 1, in <module>
#     ratios_summary(1)
#
# NameError: name 'ratios_summary' is not defined

# %%
grp_63_ret = clust_152_returns[clust_152_returns['Cluster 152']==7].iloc[:,-366:-1].T

# %%
plt.plot(grp_63_ret.cumsum())
