# %%
pip install fundamentalanalysis
# Out:
# Collecting fundamentalanalysis
#   Downloading fundamentalanalysis-0.2.14-py3-none-any.whl (12 kB)
# Installing collected packages: fundamentalanalysis
# Successfully installed fundamentalanalysis-0.2.14
# Note: you may need to restart the kernel to use updated packages.

# %%
import fundamentalanalysis as fa
import pandas as pd
import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest
from fanett import db_fundamentals_summary, download_stocks_fundamentals

api_key1 = "524132a6aa8f6bd0e848e2a03a215c48"
api_key2 = "2ce342c41d2dffffdf5d51fc185fa8b6"
api_key3 = "41cacf0260e68faa1f0e143fac6872d9"

nasdaq_tickers = ['TMUSR', 'AAPL', 'MSFT', 'AMZN', 'FB', 'GOOGL', 'GOOG', 'INTC', 'NVDA', 'ADBE',
               'PYPL', 'CSCO', 'NFLX', 'PEP', 'TSLA', 'CMCSA', 'AMGN', 'COST', 'TMUS', 'AVGO',
               'TXN', 'CHTR', 'QCOM', 'GILD', 'SBUX', 'INTU', 'VRTX', 'MDLZ', 'ISRG', 'FISV',
               'BKNG', 'ADP', '', 'ATVI', 'AMD', 'JD', 'MU', 'AMAT', 'ILMN', 'ADSK',
               'CSX', 'MELI', 'LRCX', 'ADI', 'ZM', 'BIIB', 'EA', 'KHC', 'WBA', 'LULU',
               'EBAY', 'MNST', 'DXCM', 'EXC', 'BIDU', 'XEL', 'WDAY', 'DOCU', 'SPLK', 'ORLY',
               'NXPI', 'CTSH', 'KLAC', 'SNPS', 'SGEN', 'ASML', 'IDXX', 'CSGP', 'CTAS', 'VRSK',
               'MAR', 'CDNS', 'PAYX', 'ALXN', 'MCHP', 'SIRI', 'ANSS', 'VRSN', 'FAST', 'BMRN',
               'XLNX', 'INCY','DLTR', 'SWKS', 'ALGN', 'CERN', 'CPRT', 'CTXS', 'TTWO', 'MXIM',
               'CDW', 'CHKP', 'WDC', 'ULTA', 'NTAP', 'FOXA', 'LBTYK']

# %%
nasdaq_data = np.load("nasdaq.npy", allow_pickle = True).item()
nasdaq_2021 = db_fundamentals_summary(nasdaq_tickers, nasdaq_data, year = '2021')
nasdaq_2021.head()
# Out:
#        assetTurnover  averageInventory  averagePayables  averageReceivables  \
# AAPL        1.042208      6.580000e+09     5.476300e+10        5.150600e+10
# MSFT        0.503591      2.636000e+09     1.516300e+10        3.804300e+10
# AMZN        1.117164      2.821750e+10     7.560150e+10        2.871650e+10
# FB          0.710471               NaN     2.707000e+09        1.268700e+10
# GOOGL       0.717116      9.490000e+08     5.813000e+09        3.582700e+10
#
#        bookValuePerShare  capexPerShare  capexToDepreciation  \
# AAPL            3.777557      -0.663722            -0.982364
# MSFT           18.813833      -2.732476            -1.764676
# AMZN           13.660573      -6.032905            -1.780178
# FB             44.377754      -6.598081            -2.330488
# GOOGL          18.844837      -1.845279            -1.980548
#
#        capexToOperatingCashFlow  capexToRevenue  \
# AAPL                  -0.106548       -0.030302
# MSFT                  -0.268726       -0.122686
# AMZN                  -1.317871       -0.129949
# FB                    -0.321880       -0.157442
# GOOGL                 -0.268843       -0.095638
#
#        capitalExpenditureCoverageRatio  ...       roe      roic  \
# AAPL                         -9.385476  ...  1.500713  0.483099
# MSFT                         -3.721269  ...  0.431522  0.285229
# AMZN                         -0.758800  ...  0.241340  0.089402
# FB                           -3.106749  ...  0.315265  0.322764
# GOOGL                        -3.719643  ...  0.302156  0.266814
#
#        salesGeneralAndAdministrativeToRevenue  shareholdersEquityPerShare  \
# AAPL                                 0.000000                    3.777557
# MSFT                                 0.030383                   18.813833
# AMZN                                 0.018779                   13.660573
# FB                                   0.083347                   44.377754
# GOOGL                                0.052438                   18.844837
#
#        shortTermCoverageRatios  stockBasedCompensationToRevenue  \
# AAPL                  6.663550                         0.021612
# MSFT                  9.506938                         0.036398
# AMZN                       NaN                         0.027153
# FB                   51.182786                         0.077708
# GOOGL                41.869347                         0.059681
#
#        tangibleAssetValue  tangibleBookValuePerShare  \
# AAPL                  NaN                   3.777557
# MSFT         8.447700e+10                  11.193454
# AMZN         1.177670e+11                  11.637055
# FB           1.050480e+11                  37.330490
# GOOGL        2.272620e+11                  17.019554
#
#        totalDebtToCapitalization  workingCapital
# AAPL                    0.664074    9.355000e+09
# MSFT                    0.323103    9.574900e+10
# AMZN                         NaN    1.931400e+10
# FB                      0.099984    4.553100e+10
# GOOGL                   0.101400    1.238890e+11
#
# [5 rows x 100 columns]

# %%
download_stocks_fundamentals(nasdaq_tickers[0:20],'nasdaq', api_key2)
# Out:
# 100%|███████████████████████████████████████████| 20/20 [01:26<00:00,  4.32s/it]
