# %%
import tensortrade.env.default as default
from tensortrade.oms.exchanges import Exchange
from tensortrade.feed import Stream
from tensortrade.oms.services.execution.simulated import execute_order
from tensortrade.feed.core import Stream, DataFeed, NameSpace
from tensortrade.oms.wallets import Wallet, Portfolio
from tensortrade.oms.instruments import Instrument
from tensortrade.agents import DQNAgent
from tensortrade.env.default.actions import BSH, ManagedRiskOrders
from tensortrade.env.default.rewards import RiskAdjustedReturns
from tensortrade.env.default.renderers import PlotlyTradingChart
from all_indicators import get_all_stock_indicators
from sklearn.preprocessing import MinMaxScaler
import multiprocessing
import pandas as pd
import numpy as np

pd.options.mode.use_inf_as_na = True
RMS_data = get_all_stock_indicators('RMS.PA')
AIR_data = get_all_stock_indicators('AIR.PA')
# Out:
# B:\Anaconda\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# dropped Index(['trend_psar_up', 'trend_psar_down', 'alpha26', 'alpha45', 'alpha85'], dtype='object')
# dropped Index(['trend_psar_up', 'trend_psar_down', 'alpha26', 'alpha94'], dtype='object')

# %%
from sklearn.model_selection import train_test_split

def split_data(data):
    X = data.copy().drop(columns=['Log Returns','Returns'])
    y = data.copy()['Returns']

    X_train_test, X_valid, y_train_test, y_valid = \
        train_test_split(X, y, train_size=0.8, test_size=0.2, shuffle=False)

    X_train, X_test, y_train, y_test = \
        train_test_split(X_train_test, y_train_test, train_size=0.7, test_size=0.3, shuffle=False)

    return X_train, X_test, X_valid, y_train, y_test, y_valid

RMS_X_train, RMS_X_test, RMS_X_valid, RMS_y_train, RMS_y_test, RMS_y_valid = split_data(RMS_data)
AIR_X_train, AIR_X_test, AIR_X_valid, AIR_y_train, AIR_y_test, AIR_y_valid = split_data(AIR_data)

# %%
RMS_X_train.to_pickle('RMS_X_train.pickle')
RMS_X_test.to_pickle('RMS_X_test.pickle')
RMS_X_valid.to_pickle('RMS_X_valid.pickle')
AIR_X_train.to_pickle('AIR_X_train.pickle')
AIR_X_test.to_pickle('AIR_X_test.pickle')
AIR_X_valid.to_pickle('AIR_X_valid.pickle')

# %%
import os
import pickle
cwd = os.getcwd()
RMS_train_pickle = os.path.join(cwd, 'RMS_train.pickle')
RMS_test_pickle = os.path.join(cwd, 'RMS_test.pickle')
RMS_valid_pickle = os.path.join(cwd, 'RMS_valid.pickle')

AIR_train_pickle = os.path.join(cwd, 'AIR_train.pickle')
AIR_test_pickle = os.path.join(cwd, 'AIR_test.pickle')
AIR_valid_pickle = os.path.join(cwd, 'AIR_valid.pickle')

RMS_X_train.to_pickle(RMS_train_pickle)
RMS_X_test.to_pickle(RMS_test_pickle)
RMS_X_valid.to_pickle(RMS_valid_pickle)
AIR_X_train.to_pickle(AIR_train_pickle)
AIR_X_test.to_pickle(AIR_test_pickle)
AIR_X_valid.to_pickle(AIR_valid_pickle)

# %%
def separate_render_features(stock_data, ticker):
    #ohlc prices for render
    stock_ohlc = stock_data[['Open','High','Low','Close','Volume']].copy()
    stock_ohlc['date'] = stock_ohlc.index + pd.DateOffset(hours=2)
    stock_ohlc = stock_ohlc.add_prefix(f"{ticker}:")
    
    #all features to train from + minmax scaling
    scaler = MinMaxScaler()
    stock_features = stock_data.copy()
    stock_features = stock_features.add_prefix(f"{ticker}:")
    scaler.fit(stock_features)
    stock_features_scaled = pd.DataFrame(scaler.fit_transform(stock_features), columns = stock_features.columns, index = stock_features.index)
    return stock_ohlc, stock_features_scaled

def get_price_stream(stock_renders, tickers): #list
    stock_price_stream_list = []
    for i in range(len(stock_renders)):
        stock_price_stream_list.append(Stream.source(list(stock_renders[i][f"{tickers[i]}:Close"]), dtype="float").rename(f"EUR-{tickers[i].replace('.PA', '')}"))
    return stock_price_stream_list

# %%
def create_env(config):
    RMS_data = pd.read_pickle(config['RMS_filename'])
    AIR_data = pd.read_pickle(config['AIR_filename'])
    rms_render, rms_scaled_features = separate_render_features(RMS_data, 'RMS.PA')
    air_render, air_scaled_features = separate_render_features(AIR_data, 'AIR.PA')
    price_streams = get_price_stream([rms_render, air_render], ["RMS.PA", "AIR.PA"])
    euronext = Exchange('euronext', service=execute_order)(price_streams[0], price_streams[1])

    all_scaled_features = pd.concat([rms_scaled_features, air_scaled_features], axis=1)
    with NameSpace("euronext"):
        features = [Stream.source(list(all_scaled_features[feature]), dtype="float").rename(feature) for feature in all_scaled_features.columns]
    all_features_feed = DataFeed(features)
    all_features_feed.compile()

    EUR = Instrument('EUR', 4, 'Euro')
    RMS = Instrument('RMS', 4, 'Hermes')
    AIR = Instrument('AIR', 4, 'Airbus')

    cash = Wallet(euronext, 10000 * EUR)
    asset_rms = Wallet(euronext, 0 * RMS)
    asset_air = Wallet(euronext, 0 * AIR)

    portfolio = Portfolio(EUR, [cash, asset_rms, asset_air])

    reward_scheme = RiskAdjustedReturns(return_algorithm='sortino', window_size=100)
    action_scheme = ManagedRiskOrders()

    chart_renderer = PlotlyTradingChart(
        display=True,  # show the chart on screen (default)
        height=800,  # affects both displayed and saved file height. None for 100% height.
        save_format="html",  # save the chart to an HTML file
        auto_open_html=True,  # open the saved HTML chart in a new browser tab
    )
    
    renderer_feed = DataFeed([
        Stream.source(list(rms_render["RMS.PA:date"])).rename("date"),
        Stream.source(list(rms_render["RMS.PA:Open"]), dtype="float").rename("open"),
        Stream.source(list(rms_render["RMS.PA:High"]), dtype="float").rename("high"),
        Stream.source(list(rms_render["RMS.PA:Low"]), dtype="float").rename("low"),
        Stream.source(list(rms_render["RMS.PA:Close"]), dtype="float").rename("close"), 
        Stream.source(list(rms_render["RMS.PA:Volume"]), dtype="float").rename("volume"),
        Stream.source(list(air_render["AIR.PA:date"])).rename("date"),
        Stream.source(list(air_render["AIR.PA:Open"]), dtype="float").rename("open"),
        Stream.source(list(air_render["AIR.PA:High"]), dtype="float").rename("high"),
        Stream.source(list(air_render["AIR.PA:Low"]), dtype="float").rename("low"),
        Stream.source(list(air_render["AIR.PA:Close"]), dtype="float").rename("close"), 
        Stream.source(list(air_render["AIR.PA:Volume"]), dtype="float").rename("volume"),
    ])

    env = default.create(
        portfolio=portfolio,
        action_scheme=action_scheme,
        reward_scheme=reward_scheme,
        feed=all_features_feed,
        renderer_feed=renderer_feed,
        renderer=chart_renderer,
        window_size=config["window_size"],
        max_allowed_loss=config["max_allowed_loss"]
    )
    
    return env

# %%
import ray
from ray import tune
from ray.tune.registry import register_env

ray.init(num_cpus=6,
         include_dashboard=True,
         ignore_reinit_error=True)

register_env("TradingEnv", create_env)
# Out:
# 2022-12-13 00:11:00,048	INFO worker.py:1519 -- Started a local Ray instance. View the dashboard at 127.0.0.1:8265

# %%
env1 = create_env({
    "RMS_filename": "RMS_X_test.pickle", 
    "AIR_filename": "AIR_X_test.pickle",  
    "max_allowed_loss": 0.10, 
    "window_size": 30 
})

# %%
from ray.tune.schedulers import ASHAScheduler
from ray.tune.suggest import ConcurrencyLimiter
from ray.tune.suggest.optuna import OptunaSearch

LR = tune.loguniform(1e-5, 1e-2)
GAMMA = tune.uniform(0.8, 0.9999)
LAMBDA = tune.uniform(0.1, 0.8)
VF_LOSS_COEFF = tune.uniform(0.01, 1.0)
ENTROPY_COEFF = tune.uniform(1e-8, 1e-1)

checkpoint_metric = 'episode_reward_mean'

# Specific configuration keys that will be used during training
env_config_training = {
    "RMS_filename": RMS_train_pickle, 
    "AIR_filename": AIR_train_pickle,  
    "max_allowed_loss": 0.10, 
    "window_size": 30 
}
# Specific configuration keys that will be used during evaluation (only the overridden ones)
env_config_evaluation = {
    "RMS_filename": RMS_test_pickle, 
    "AIR_filename": AIR_test_pickle,  
    "max_allowed_loss": 1.0, 
    "window_size": 30 
}

search_alg = OptunaSearch()
search_alg = ConcurrencyLimiter(search_alg, max_concurrent=4)

scheduler = ASHAScheduler()

import time
start = time.time()
analysis = tune.run(
    "PPO",
    stop={
        "episode_reward_mean": 5000,
        "training_iteration": 35,
    },
    verbose=3,
    config={
        "env": "TradingEnv",
        "env_config": env_config_training,
        "log_level": "ERROR",
        #"log_level": "INFO",
        #"log_level": "DEBUG",
        "framework": "torch",
        "ignore_worker_failures": True,
        "num_workers": 2,
        "num_gpus": 0,
        "clip_rewards": True,
        "lr": LR,
        "lr_schedule": [
            [0, 1e-1],
            [int(1e2), 1e-2],
            [int(1e3), 1e-3],
            [int(1e4), 1e-4],
            [int(1e5), 1e-5],
            [int(1e6), 1e-6],
            [int(1e7), 1e-7]
        ],
        "model": {
            "use_lstm": True,
            "lstm_cell_size": 512
        },
        "gamma": GAMMA,
        "observation_filter": "MeanStdFilter",
        "lambda": LAMBDA,
        "vf_share_layers": True,
        "vf_loss_coeff": VF_LOSS_COEFF,
        "entropy_coeff": ENTROPY_COEFF,
        "evaluation_interval": 1,  # Run evaluation on every iteration
        "evaluation_config": {
            "env_config": env_config_evaluation,  # The dictionary we built before (only the overriding keys to use in evaluation)
            "explore": False,  # We don't want to explore during evaluation. All actions have to be repeatable.
        },
    },
    metric=checkpoint_metric,
    mode="max",
    search_alg=search_alg,
    scheduler=scheduler,
    num_samples=10,  # Samples per hyperparameter combination. More averages out randomness. Less runs faster
    #resources_per_trial={"cpu": 2},
    keep_checkpoints_num=10,  # Keep the last 10 checkpoints
    checkpoint_freq=1,  # Do a checkpoint on each iteration (slower but you can pick more finely the checkpoint to use later)
    resume="AUTO",
)
taken = time.time() - start
print(f"Time taken: {taken:.2f} seconds.")
print(f"Best config: {analysis.best_config}")
# Out:
# C:\Users\remik\AppData\Local\Temp\ipykernel_24848\25655878.py:2: DeprecationWarning: The module `ray.tune.suggest` has been moved to `ray.tune.search` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest` with `ray.tune.search`.
#   from ray.tune.suggest import ConcurrencyLimiter
# C:\Users\remik\AppData\Local\Temp\ipykernel_24848\25655878.py:3: DeprecationWarning: The module `ray.tune.suggest.optuna` has been moved to `ray.tune.search.optuna` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.optuna` with `ray.tune.search.optuna`.
#   from ray.tune.suggest.optuna import OptunaSearch
# [I 2022-12-13 00:11:04,600] A new study created in memory with name: optuna
# 2022-12-13 00:11:04,625	INFO trial_runner.py:596 -- No local checkpoint was found. Ray Tune will now start a new experiment.
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2022-12-13 01:10:53</td></tr>
# <tr><td>Running for: </td><td>00:59:48.41        </td></tr>
# <tr><td>Memory:      </td><td>11.7/16.0 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using AsyncHyperBand: num_stopped=0<br>Bracket: Iter 64.000: None | Iter 16.000: None | Iter 4.000: None | Iter 1.000: -2197556.272468028<br>Resources requested: 6.0/6 CPUs, 0/1 GPUs, 0.0/1.75 GiB heap, 0.0/0.88 GiB objects
#     </div>
#     <div class="vDivider"></div>
# <div class="messages">
#   <h3>Messages</h3>
#
#
#   Number of errored trials: 1<br><table>
# <thead>
# <tr><th>Trial name             </th><th style="text-align: right;">  # failures</th><th>error file                                                                                                                                                                                     </th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_TradingEnv_4d0ed2cc</td><td style="text-align: right;">           1</td><td>C:\Users\remik\ray_results\PPO\PPO_TradingEnv_4d0ed2cc_2_clip_rewards=True,entropy_coeff=0.0489,env=TradingEnv,AIR_filename=D_Trading_ACP_ProjetFinance_AIR_train_2022-12-13_00-11-25\error.txt</td></tr>
# </tbody>
# </table>
# </div>
# <style>
# .messages {
#   color: var(--jp-ui-font-color1);
#   display: flex;
#   flex-direction: column;
#   padding-left: 1em;
#   overflow-y: auto;
# }
# .messages h3 {
#   font-weight: bold;
# }
# .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name             </th><th>status  </th><th>loc            </th><th style="text-align: right;">  entropy_coeff</th><th style="text-align: right;">   gamma</th><th style="text-align: right;">  lambda</th><th style="text-align: right;">         lr</th><th style="text-align: right;">  vf_loss_coeff</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  ts</th><th style="text-align: right;">      reward</th><th style="text-align: right;">  num_recreated_worker
# s</th><th style="text-align: right;">  episode_reward_max</th><th style="text-align: right;">  episode_reward_min</th></tr>
# </thead>
# <tbody>
# <tr><td>PPO_TradingEnv_408e835f</td><td>RUNNING </td><td>127.0.0.1:26548</td><td style="text-align: right;">      0.0854735</td><td style="text-align: right;">0.986189</td><td style="text-align: right;">0.103988</td><td style="text-align: right;">0.000109374</td><td style="text-align: right;">      0.543246 </td><td style="text-align: right;">     2</td><td style="text-align: right;">         2409.33</td><td style="text-align: right;">8000</td><td style="text-align: right;">-3.05045e+06</td><td style="text-align: right;">0</td><td style="text-align: right;">             7.44193</td><td style="text-align: right;">        -1.16316e+07</td></tr>
# <tr><td>PPO_TradingEnv_59d1c2bb</td><td>RUNNING </td><td>127.0.0.1:19488</td><td style="text-align: right;">      0.0369116</td><td style="text-align: right;">0.94655 </td><td style="text-align: right;">0.104093</td><td style="text-align: right;">3.41156e-05</td><td style="text-align: right;">      0.701    </td><td style="text-align: right;">     2</td><td style="text-align: right;">         2398.46</td><td style="text-align: right;">8000</td><td style="text-align: right;">-2.02776e+06</td><td style="text-align: right;">0</td><td style="text-align: right;">             6.13659</td><td style="text-align: right;">        -8.27408e+06</td></tr>
# <tr><td>PPO_TradingEnv_5be00eaa</td><td>PENDING </td><td>               </td><td style="text-align: right;">      0.0490548</td><td style="text-align: right;">0.832678</td><td style="text-align: right;">0.767172</td><td style="text-align: right;">0.000261807</td><td style="text-align: right;">      0.0576734</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">            </td><td style="text-align: right;"> </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td></tr>
# <tr><td>PPO_TradingEnv_4d0ed2cc</td><td>ERROR   </td><td>               </td><td style="text-align: right;">      0.0488513</td><td style="text-align: right;">0.844165</td><td style="text-align: right;">0.52905 </td><td style="text-align: right;">1.15522e-05</td><td style="text-align: right;">      0.0973891</td><td style="text-align: right;">      </td><td style="text-align: right;">                </td><td style="text-align: right;">    </td><td style="text-align: right;">            </td><td style="text-align: right;"> </td><td style="text-align: right;">                    </td><td style="text-align: right;">                    </td></tr>
# </tbody>
# </table>
#   </div>
# </div>
# <style>
# .tuneStatus {
#   color: var(--jp-ui-font-color1);
# }
# .tuneStatus .systemInfo {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus td {
#   white-space: nowrap;
# }
# .tuneStatus .trialStatus {
#   display: flex;
#   flex-direction: column;
# }
# .tuneStatus h3 {
#   font-weight: bold;
# }
# .tuneStatus .hDivider {
#   border-bottom-width: var(--jp-border-width);
#   border-bottom-color: var(--jp-border-color0);
#   border-bottom-style: solid;
# }
# .tuneStatus .vDivider {
#   border-left-width: var(--jp-border-width);
#   border-left-color: var(--jp-border-color0);
#   border-left-style: solid;
#   margin: 0.5em 1em 0.5em 1em;
# }
# </style>
# (pid=26548) B:\Anaconda\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
# (pid=26548)   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# (pid=26548) B:\Anaconda\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
# (pid=26548)   "class": algorithms.Blowfish,
# (PPO pid=26548) 2022-12-13 00:11:13,823	INFO ppo.py:379 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# (PPO pid=26548) 2022-12-13 00:11:13,824	INFO algorithm.py:457 -- Current log_level is ERROR. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=13512) B:\Anaconda\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
# (pid=13512)   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# (pid=27692) B:\Anaconda\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
# (pid=27692)   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# (pid=13512) B:\Anaconda\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
# (pid=13512)   "class": algorithms.Blowfish,
# (pid=27692) B:\Anaconda\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
# (pid=27692)   "class": algorithms.Blowfish,
# (PPO pid=26548) 2022-12-13 00:11:25,586	INFO trainable.py:164 -- Trainable.setup took 11.764 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (PPO pid=26548) 2022-12-13 00:11:25,587	WARNING util.py:66 -- Install gputil for GPU system monitoring.
# (pid=25552) B:\Anaconda\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
# (pid=25552)   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# (pid=25552) B:\Anaconda\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
# (pid=25552)   "class": algorithms.Blowfish,
# (PPO pid=25552) 2022-12-13 00:11:35,469	INFO ppo.py:379 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# (PPO pid=25552) 2022-12-13 00:11:35,471	INFO algorithm.py:457 -- Current log_level is ERROR. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (PPO pid=26548) 2022-12-13 00:11:36,786	ERROR algorithm.py:2605 -- Error in training or evaluation attempt! Trying to recover.
# (PPO pid=26548) Traceback (most recent call last):
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\algorithms\algorithm.py", line 2948, in _run_one_training_iteration
# (PPO pid=26548)     results = self.training_step()
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\util\tracing\tracing_helper.py", line 466, in _resume_span
# (PPO pid=26548)     return method(self, *_args, **_kwargs)
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\algorithms\ppo\ppo.py", line 408, in training_step
# (PPO pid=26548)     train_batch = synchronous_parallel_sample(
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\execution\rollout_ops.py", line 100, in synchronous_parallel_sample
# (PPO pid=26548)     sample_batches = ray.get(
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
# (PPO pid=26548)     return func(*args, **kwargs)
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\worker.py", line 2289, in get
# (PPO pid=26548)     raise value.as_instanceof_cause()
# (PPO pid=26548) ray.exceptions.RayTaskError(RayOutOfMemoryError): ray::RolloutWorker.sample() (pid=27692, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001F4E86037C0>)
# (PPO pid=26548)   File "python\ray\_raylet.pyx", line 817, in ray._raylet.execute_task
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
# (PPO pid=26548)     raise RayOutOfMemoryError(
# (PPO pid=26548) ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-N80GTVU is used (15.22 / 15.95 GB). The top 10 memory consumers are:
# (PPO pid=26548)
# (PPO pid=26548) PID	MEM	COMMAND
# (PPO pid=26548) 7012	2.44GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# (PPO pid=26548) 17948	1.95GiB	B:\Anaconda\pythonw.exe B:\Anaconda\Scripts\anaconda-navigator-script.py
# (PPO pid=26548) 27692	0.67GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 13512	0.66GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 26548	0.59GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 24848	0.55GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=26548) 25552	0.46GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 12452	0.38GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=26548) 11564	0.38GiB	B:\Anaconda\python.exe B:\Anaconda\Scripts\spyder-script.py
# (PPO pid=26548) 5180	0.32GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# (PPO pid=26548)
# (PPO pid=26548) In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# (PPO pid=26548) ---
# (PPO pid=26548) --- Tip: Use the `ray memory` command to list active objects in the cluster.
# (PPO pid=26548) --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# (PPO pid=26548) ---
# (PPO pid=26548) 2022-12-13 00:11:39,583	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::RolloutWorker.sample() (pid=13512, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000021460873790>)
# (PPO pid=26548)   File "python\ray\_raylet.pyx", line 817, in ray._raylet.execute_task
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
# (PPO pid=26548)     raise RayOutOfMemoryError(
# (PPO pid=26548) ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-N80GTVU is used (15.22 / 15.95 GB). The top 10 memory consumers are:
# (PPO pid=26548)
# (PPO pid=26548) PID	MEM	COMMAND
# (PPO pid=26548) 7012	2.44GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# (PPO pid=26548) 17948	1.95GiB	B:\Anaconda\pythonw.exe B:\Anaconda\Scripts\anaconda-navigator-script.py
# (PPO pid=26548) 27692	0.67GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 13512	0.66GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 26548	0.59GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 24848	0.55GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=26548) 25552	0.46GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 12452	0.38GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=26548) 11564	0.38GiB	B:\Anaconda\python.exe B:\Anaconda\Scripts\spyder-script.py
# (PPO pid=26548) 5180	0.32GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# (PPO pid=26548)
# (PPO pid=26548) In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# (PPO pid=26548) ---
# (PPO pid=26548) --- Tip: Use the `ray memory` command to list active objects in the cluster.
# (PPO pid=26548) --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# (PPO pid=26548) ---
# (PPO pid=26548) 2022-12-13 00:11:39,630	ERROR algorithm.py:2605 -- Error in training or evaluation attempt! Trying to recover.
# (PPO pid=26548) Traceback (most recent call last):
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\algorithms\algorithm.py", line 2948, in _run_one_training_iteration
# (PPO pid=26548)     results = self.training_step()
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\util\tracing\tracing_helper.py", line 466, in _resume_span
# (PPO pid=26548)     return method(self, *_args, **_kwargs)
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\algorithms\ppo\ppo.py", line 408, in training_step
# (PPO pid=26548)     train_batch = synchronous_parallel_sample(
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\execution\rollout_ops.py", line 100, in synchronous_parallel_sample
# (PPO pid=26548)     sample_batches = ray.get(
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
# (PPO pid=26548)     return func(*args, **kwargs)
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\worker.py", line 2289, in get
# (PPO pid=26548)     raise value.as_instanceof_cause()
# (PPO pid=26548) ray.exceptions.RayTaskError(RayOutOfMemoryError): ray::RolloutWorker.sample() (pid=13512, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000021460873790>)
# (PPO pid=26548)   File "python\ray\_raylet.pyx", line 817, in ray._raylet.execute_task
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
# (PPO pid=26548)     raise RayOutOfMemoryError(
# (PPO pid=26548) ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-N80GTVU is used (15.37 / 15.95 GB). The top 10 memory consumers are:
# (PPO pid=26548)
# (PPO pid=26548) PID	MEM	COMMAND
# (PPO pid=26548) 7012	2.44GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# (PPO pid=26548) 17948	1.95GiB	B:\Anaconda\pythonw.exe B:\Anaconda\Scripts\anaconda-navigator-script.py
# (PPO pid=26548) 27692	0.68GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 13512	0.67GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 26548	0.59GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 24848	0.55GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=26548) 25552	0.46GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 12452	0.38GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=26548) 11564	0.37GiB	B:\Anaconda\python.exe B:\Anaconda\Scripts\spyder-script.py
# (PPO pid=26548) 5180	0.32GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# (PPO pid=26548)
# (PPO pid=26548) In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# (PPO pid=26548) ---
# (PPO pid=26548) --- Tip: Use the `ray memory` command to list active objects in the cluster.
# (PPO pid=26548) --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# (PPO pid=26548) ---
# (pid=10120) B:\Anaconda\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
# (pid=10120)   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# (pid=20348) B:\Anaconda\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
# (pid=20348)   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# (PPO pid=26548) 2022-12-13 00:11:42,577	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::RolloutWorker.sample() (pid=27692, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001F4E86037C0>)
# (PPO pid=26548)   File "python\ray\_raylet.pyx", line 817, in ray._raylet.execute_task
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
# (PPO pid=26548)     raise RayOutOfMemoryError(
# (PPO pid=26548) ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-N80GTVU is used (15.37 / 15.95 GB). The top 10 memory consumers are:
# (PPO pid=26548)
# (PPO pid=26548) PID	MEM	COMMAND
# (PPO pid=26548) 7012	2.44GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# (PPO pid=26548) 17948	1.95GiB	B:\Anaconda\pythonw.exe B:\Anaconda\Scripts\anaconda-navigator-script.py
# (PPO pid=26548) 27692	0.68GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 13512	0.67GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 26548	0.59GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 24848	0.55GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=26548) 25552	0.46GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 12452	0.38GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=26548) 11564	0.37GiB	B:\Anaconda\python.exe B:\Anaconda\Scripts\spyder-script.py
# (PPO pid=26548) 5180	0.32GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# (PPO pid=26548)
# (PPO pid=26548) In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# (PPO pid=26548) ---
# (PPO pid=26548) --- Tip: Use the `ray memory` command to list active objects in the cluster.
# (PPO pid=26548) --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# (PPO pid=26548) ---
# (PPO pid=26548) 2022-12-13 00:11:42,619	ERROR algorithm.py:2605 -- Error in training or evaluation attempt! Trying to recover.
# (PPO pid=26548) Traceback (most recent call last):
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\algorithms\algorithm.py", line 2948, in _run_one_training_iteration
# (PPO pid=26548)     results = self.training_step()
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\util\tracing\tracing_helper.py", line 466, in _resume_span
# (PPO pid=26548)     return method(self, *_args, **_kwargs)
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\algorithms\ppo\ppo.py", line 408, in training_step
# (PPO pid=26548)     train_batch = synchronous_parallel_sample(
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\execution\rollout_ops.py", line 100, in synchronous_parallel_sample
# (PPO pid=26548)     sample_batches = ray.get(
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
# (PPO pid=26548)     return func(*args, **kwargs)
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\worker.py", line 2289, in get
# (PPO pid=26548)     raise value.as_instanceof_cause()
# (PPO pid=26548) ray.exceptions.RayTaskError(RayOutOfMemoryError): ray::RolloutWorker.sample() (pid=27692, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001F4E86037C0>)
# (PPO pid=26548)   File "python\ray\_raylet.pyx", line 817, in ray._raylet.execute_task
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
# (PPO pid=26548)     raise RayOutOfMemoryError(
# (PPO pid=26548) ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-N80GTVU is used (15.43 / 15.95 GB). The top 10 memory consumers are:
# (PPO pid=26548)
# (PPO pid=26548) PID	MEM	COMMAND
# (PPO pid=26548) 7012	2.44GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# (PPO pid=26548) 17948	1.95GiB	B:\Anaconda\pythonw.exe B:\Anaconda\Scripts\anaconda-navigator-script.py
# (PPO pid=26548) 27692	0.69GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 13512	0.68GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 26548	0.59GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 24848	0.55GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=26548) 25552	0.46GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 12452	0.38GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=26548) 11564	0.38GiB	B:\Anaconda\python.exe B:\Anaconda\Scripts\spyder-script.py
# (PPO pid=26548) 5180	0.32GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# (PPO pid=26548)
# (PPO pid=26548) In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# (PPO pid=26548) ---
# (PPO pid=26548) --- Tip: Use the `ray memory` command to list active objects in the cluster.
# (PPO pid=26548) --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# (PPO pid=26548) ---
# (pid=10120) B:\Anaconda\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
# (pid=10120)   "class": algorithms.Blowfish,
# (pid=20348) B:\Anaconda\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
# (pid=20348)   "class": algorithms.Blowfish,
# (PPO pid=25552) 2022-12-13 00:11:44,614	ERROR worker.py:763 -- Exception raised in creation task: The actor died because of an error raised in its creation task, ray::PPO.__init__() (pid=25552, ip=127.0.0.1, repr=PPO)
# (PPO pid=25552)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\evaluation\worker_set.py", line 139, in __init__
# (PPO pid=25552)     self.add_workers(
# (PPO pid=25552)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\evaluation\worker_set.py", line 490, in add_workers
# (PPO pid=25552)     self.foreach_worker(lambda w: w.assert_healthy())
# (PPO pid=25552)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\evaluation\worker_set.py", line 620, in foreach_worker
# (PPO pid=25552)     remote_results = ray.get([w.apply.remote(func) for w in self.remote_workers()])
# (PPO pid=25552)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
# (PPO pid=25552)     return func(*args, **kwargs)
# (PPO pid=25552)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\worker.py", line 2291, in get
# (PPO pid=25552)     raise value
# (PPO pid=25552) ray.exceptions.RayActorError: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=10120, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001DB632C3760>)
# (PPO pid=25552)   File "python\ray\_raylet.pyx", line 817, in ray._raylet.execute_task
# (PPO pid=25552)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
# (PPO pid=25552)     raise RayOutOfMemoryError(
# (PPO pid=25552) ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-N80GTVU is used (15.21 / 15.95 GB). The top 10 memory consumers are:
# (PPO pid=25552)
# (PPO pid=25552) PID	MEM	COMMAND
# (PPO pid=25552) 7012	2.44GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# (PPO pid=25552) 17948	1.95GiB	B:\Anaconda\pythonw.exe B:\Anaconda\Scripts\anaconda-navigator-script.py
# (PPO pid=25552) 13512	0.68GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=25552) 27692	0.66GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=25552) 26548	0.59GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=25552) 24848	0.55GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=25552) 25552	0.46GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=25552) 10120	0.41GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=25552) 20348	0.41GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=25552) 12452	0.38GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=25552)
# (PPO pid=25552) In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# (PPO pid=25552) ---
# (PPO pid=25552) --- Tip: Use the `ray memory` command to list active objects in the cluster.
# (PPO pid=25552) --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# (PPO pid=25552) ---
# (PPO pid=25552)
# (PPO pid=25552) During handling of the above exception, another exception occurred:
# (PPO pid=25552)
# (PPO pid=25552) ray::PPO.__init__() (pid=25552, ip=127.0.0.1, repr=PPO)
# (PPO pid=25552)   File "python\ray\_raylet.pyx", line 852, in ray._raylet.execute_task
# (PPO pid=25552)   File "python\ray\_raylet.pyx", line 906, in ray._raylet.execute_task
# (PPO pid=25552)   File "python\ray\_raylet.pyx", line 859, in ray._raylet.execute_task
# (PPO pid=25552)   File "python\ray\_raylet.pyx", line 863, in ray._raylet.execute_task
# (PPO pid=25552)   File "python\ray\_raylet.pyx", line 810, in ray._raylet.execute_task.function_executor
# (PPO pid=25552)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\function_manager.py", line 674, in actor_method_executor
# (PPO pid=25552)     return method(__ray_actor, *args, **kwargs)
# (PPO pid=25552)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\util\tracing\tracing_helper.py", line 466, in _resume_span
# (PPO pid=25552)     return method(self, *_args, **_kwargs)
# (PPO pid=25552)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\algorithms\algorithm.py", line 414, in __init__
# (PPO pid=25552)     super().__init__(config=config, logger_creator=logger_creator, **kwargs)
# (PPO pid=25552)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\tune\trainable\trainable.py", line 161, in __init__
# (PPO pid=25552)     self.setup(copy.deepcopy(self.config))
# (PPO pid=25552)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\util\tracing\tracing_helper.py", line 466, in _resume_span
# (PPO pid=25552)     return method(self, *_args, **_kwargs)
# (PPO pid=25552)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\algorithms\algorithm.py", line 549, in setup
# (PPO pid=25552)     raise e.args[0].args[2]
# (PPO pid=25552) ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-N80GTVU is used (15.21 / 15.95 GB). The top 10 memory consumers are:
# (PPO pid=25552)
# (PPO pid=25552) PID	MEM	COMMAND
# (PPO pid=25552) 7012	2.44GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# (PPO pid=25552) 17948	1.95GiB	B:\Anaconda\pythonw.exe B:\Anaconda\Scripts\anaconda-navigator-script.py
# (PPO pid=25552) 13512	0.68GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=25552) 27692	0.66GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=25552) 26548	0.59GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=25552) 24848	0.55GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=25552) 25552	0.46GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=25552) 10120	0.41GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=25552) 20348	0.41GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=25552) 12452	0.38GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=25552)
# (PPO pid=25552) In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# (PPO pid=25552) ---
# (PPO pid=25552) --- Tip: Use the `ray memory` command to list active objects in the cluster.
# (PPO pid=25552) --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# (PPO pid=25552) ---
# (RolloutWorker pid=10120) 2022-12-13 00:11:44,598	ERROR worker.py:763 -- Exception raised in creation task: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=10120, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001DB632C3760>)
# (RolloutWorker pid=10120)   File "python\ray\_raylet.pyx", line 817, in ray._raylet.execute_task
# (RolloutWorker pid=10120)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
# (RolloutWorker pid=10120)     raise RayOutOfMemoryError(
# (RolloutWorker pid=10120) ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-N80GTVU is used (15.21 / 15.95 GB). The top 10 memory consumers are:
# (RolloutWorker pid=10120)
# (RolloutWorker pid=10120) PID	MEM	COMMAND
# (RolloutWorker pid=10120) 7012	2.44GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# (RolloutWorker pid=10120) 17948	1.95GiB	B:\Anaconda\pythonw.exe B:\Anaconda\Scripts\anaconda-navigator-script.py
# (RolloutWorker pid=10120) 13512	0.68GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (RolloutWorker pid=10120) 27692	0.66GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (RolloutWorker pid=10120) 26548	0.59GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (RolloutWorker pid=10120) 24848	0.55GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (RolloutWorker pid=10120) 25552	0.46GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (RolloutWorker pid=10120) 10120	0.41GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (RolloutWorker pid=10120) 20348	0.41GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (RolloutWorker pid=10120) 12452	0.38GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (RolloutWorker pid=10120)
# (RolloutWorker pid=10120) In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# (RolloutWorker pid=10120) ---
# (RolloutWorker pid=10120) --- Tip: Use the `ray memory` command to list active objects in the cluster.
# (RolloutWorker pid=10120) --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# (RolloutWorker pid=10120) ---
# (PPO pid=26548) 2022-12-13 00:11:45,737	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::RolloutWorker.sample() (pid=13512, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000021460873790>)
# (PPO pid=26548)   File "python\ray\_raylet.pyx", line 817, in ray._raylet.execute_task
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
# (PPO pid=26548)     raise RayOutOfMemoryError(
# (PPO pid=26548) ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-N80GTVU is used (15.43 / 15.95 GB). The top 10 memory consumers are:
# (PPO pid=26548)
# (PPO pid=26548) PID	MEM	COMMAND
# (PPO pid=26548) 7012	2.44GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# (PPO pid=26548) 17948	1.95GiB	B:\Anaconda\pythonw.exe B:\Anaconda\Scripts\anaconda-navigator-script.py
# (PPO pid=26548) 27692	0.69GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 13512	0.68GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 26548	0.59GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 24848	0.55GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=26548) 25552	0.46GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 12452	0.38GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=26548) 11564	0.38GiB	B:\Anaconda\python.exe B:\Anaconda\Scripts\spyder-script.py
# (PPO pid=26548) 5180	0.32GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# (PPO pid=26548)
# (PPO pid=26548) In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# (PPO pid=26548) ---
# (PPO pid=26548) --- Tip: Use the `ray memory` command to list active objects in the cluster.
# (PPO pid=26548) --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# (PPO pid=26548) ---
# (PPO pid=26548) 2022-12-13 00:11:45,780	ERROR algorithm.py:2605 -- Error in training or evaluation attempt! Trying to recover.
# (PPO pid=26548) Traceback (most recent call last):
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\algorithms\algorithm.py", line 2948, in _run_one_training_iteration
# (PPO pid=26548)     results = self.training_step()
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\util\tracing\tracing_helper.py", line 466, in _resume_span
# (PPO pid=26548)     return method(self, *_args, **_kwargs)
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\algorithms\ppo\ppo.py", line 408, in training_step
# (PPO pid=26548)     train_batch = synchronous_parallel_sample(
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\execution\rollout_ops.py", line 100, in synchronous_parallel_sample
# (PPO pid=26548)     sample_batches = ray.get(
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
# (PPO pid=26548)     return func(*args, **kwargs)
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\worker.py", line 2289, in get
# (PPO pid=26548)     raise value.as_instanceof_cause()
# (PPO pid=26548) ray.exceptions.RayTaskError(RayOutOfMemoryError): ray::RolloutWorker.sample() (pid=27692, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001F4E86037C0>)
# (PPO pid=26548)   File "python\ray\_raylet.pyx", line 817, in ray._raylet.execute_task
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
# (PPO pid=26548)     raise RayOutOfMemoryError(
# (PPO pid=26548) ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-N80GTVU is used (15.22 / 15.95 GB). The top 10 memory consumers are:
# (PPO pid=26548)
# (PPO pid=26548) PID	MEM	COMMAND
# (PPO pid=26548) 7012	2.44GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# (PPO pid=26548) 17948	1.95GiB	B:\Anaconda\pythonw.exe B:\Anaconda\Scripts\anaconda-navigator-script.py
# (PPO pid=26548) 27692	0.69GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 13512	0.69GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 26548	0.59GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 24848	0.55GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=26548) 25552	0.46GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 20348	0.46GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 10120	0.42GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 12452	0.38GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=26548)
# (PPO pid=26548) In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# (PPO pid=26548) ---
# (PPO pid=26548) --- Tip: Use the `ray memory` command to list active objects in the cluster.
# (PPO pid=26548) --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# (PPO pid=26548) ---
# 2022-12-13 00:11:47,026	ERROR trial_runner.py:993 -- Trial PPO_TradingEnv_4d0ed2cc: Error processing event.
# ray.tune.error._TuneNoNextExecutorEventError: Traceback (most recent call last):
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\tune\execution\ray_trial_executor.py", line 1050, in get_next_executor_event
#     future_result = ray.get(ready_future)
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\worker.py", line 2291, in get
#     raise value
# ray.exceptions.RayActorError: The actor died because of an error raised in its creation task, ray::PPO.__init__() (pid=25552, ip=127.0.0.1, repr=PPO)
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\evaluation\worker_set.py", line 139, in __init__
#     self.add_workers(
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\evaluation\worker_set.py", line 490, in add_workers
#     self.foreach_worker(lambda w: w.assert_healthy())
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\evaluation\worker_set.py", line 620, in foreach_worker
#     remote_results = ray.get([w.apply.remote(func) for w in self.remote_workers()])
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\worker.py", line 2291, in get
#     raise value
# ray.exceptions.RayActorError: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=10120, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001DB632C3760>)
#   File "python\ray\_raylet.pyx", line 817, in ray._raylet.execute_task
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
#     raise RayOutOfMemoryError(
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-N80GTVU is used (15.21 / 15.95 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 7012	2.44GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# 17948	1.95GiB	B:\Anaconda\pythonw.exe B:\Anaconda\Scripts\anaconda-navigator-script.py
# 13512	0.68GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# 27692	0.66GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# 26548	0.59GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# 24848	0.55GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# 25552	0.46GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# 10120	0.41GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# 20348	0.41GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# 12452	0.38GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---
#
# During handling of the above exception, another exception occurred:
#
# ray::PPO.__init__() (pid=25552, ip=127.0.0.1, repr=PPO)
#   File "python\ray\_raylet.pyx", line 852, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 906, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 859, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 863, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 810, in ray._raylet.execute_task.function_executor
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\function_manager.py", line 674, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\util\tracing\tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\algorithms\algorithm.py", line 414, in __init__
#     super().__init__(config=config, logger_creator=logger_creator, **kwargs)
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\tune\trainable\trainable.py", line 161, in __init__
#     self.setup(copy.deepcopy(self.config))
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\util\tracing\tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\algorithms\algorithm.py", line 549, in setup
#     raise e.args[0].args[2]
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-N80GTVU is used (15.21 / 15.95 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# ...
# 2022-12-13 00:11:47,051	ERROR ray_trial_executor.py:111 -- An exception occurred when trying to stop the Ray actor:Traceback (most recent call last):
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\tune\execution\ray_trial_executor.py", line 102, in _post_stop_cleanup
#     ray.get(future, timeout=timeout)
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\worker.py", line 2291, in get
#     raise value
# ray.exceptions.RayActorError: The actor died because of an error raised in its creation task, ray::PPO.__init__() (pid=25552, ip=127.0.0.1, repr=PPO)
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\evaluation\worker_set.py", line 139, in __init__
#     self.add_workers(
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\evaluation\worker_set.py", line 490, in add_workers
#     self.foreach_worker(lambda w: w.assert_healthy())
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\evaluation\worker_set.py", line 620, in foreach_worker
#     remote_results = ray.get([w.apply.remote(func) for w in self.remote_workers()])
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\client_mode_hook.py", line 105, in wrapper
#     return func(*args, **kwargs)
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\worker.py", line 2291, in get
#     raise value
# ray.exceptions.RayActorError: The actor died because of an error raised in its creation task, ray::RolloutWorker.__init__() (pid=10120, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x000001DB632C3760>)
#   File "python\ray\_raylet.pyx", line 817, in ray._raylet.execute_task
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
#     raise RayOutOfMemoryError(
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-N80GTVU is used (15.21 / 15.95 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 7012	2.44GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# 17948	1.95GiB	B:\Anaconda\pythonw.exe B:\Anaconda\Scripts\anaconda-navigator-script.py
# 13512	0.68GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# 27692	0.66GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# 26548	0.59GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# 24848	0.55GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# 25552	0.46GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# 10120	0.41GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# 20348	0.41GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# 12452	0.38GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---
#
# During handling of the above exception, another exception occurred:
#
# ray::PPO.__init__() (pid=25552, ip=127.0.0.1, repr=PPO)
#   File "python\ray\_raylet.pyx", line 852, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 906, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 859, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 863, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 810, in ray._raylet.execute_task.function_executor
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\function_manager.py", line 674, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\util\tracing\tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\algorithms\algorithm.py", line 414, in __init__
#     super().__init__(config=config, logger_creator=logger_creator, **kwargs)
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\tune\trainable\trainable.py", line 161, in __init__
#     self.setup(copy.deepcopy(self.config))
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\util\tracing\tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\rllib\algorithms\algorithm.py", line 549, in setup
#     raise e.args[0].args[2]
# ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-N80GTVU is used (15.21 / 15.95 GB). The top 10 memory consumers are:
#
# PID	MEM	COMMAND
# 7012	2.44GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# 17948	1.95GiB	B:\Anaconda\pythonw.exe B:\Anaconda\Scripts\anaconda-navigator-script.py
# 13512	0.68GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# 27692	0.66GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# 26548	0.59GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# 24848	0.55GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# 25552	0.46GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# 10120	0.41GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# 20348	0.41GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# 12452	0.38GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
#
# In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# ---
# --- Tip: Use the `ray memory` command to list active objects in the cluster.
# --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# ---
#
# (PPO pid=26548) 2022-12-13 00:11:49,053	ERROR worker.py:400 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::RolloutWorker.sample() (pid=13512, ip=127.0.0.1, repr=<ray.rllib.evaluation.rollout_worker.RolloutWorker object at 0x0000021460873790>)
# (PPO pid=26548)   File "python\ray\_raylet.pyx", line 817, in ray._raylet.execute_task
# (PPO pid=26548)   File "C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\memory_monitor.py", line 162, in raise_if_low_memory
# (PPO pid=26548)     raise RayOutOfMemoryError(
# (PPO pid=26548) ray._private.memory_monitor.RayOutOfMemoryError: More than 95% of the memory on node DESKTOP-N80GTVU is used (15.22 / 15.95 GB). The top 10 memory consumers are:
# (PPO pid=26548)
# (PPO pid=26548) PID	MEM	COMMAND
# (PPO pid=26548) 7012	2.44GiB	C:\Program Files (x86)\Google\Chrome\Application\chrome.exe --type=renderer --lang=fr --device-scale
# (PPO pid=26548) 17948	1.95GiB	B:\Anaconda\pythonw.exe B:\Anaconda\Scripts\anaconda-navigator-script.py
# (PPO pid=26548) 27692	0.69GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 13512	0.69GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 26548	0.59GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 24848	0.55GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=26548) 25552	0.46GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 20348	0.46GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 10120	0.42GiB	B:\Anaconda\python.exe C:\Users\remik\AppData\Roaming\Python\Python39\site-packages\ray\_private\wor
# (PPO pid=26548) 12452	0.38GiB	B:\Anaconda\python.exe -m spyder_kernels.console -f C:\Users\remik\AppData\Roaming\jupyter\runtime\k
# (PPO pid=26548)
# (PPO pid=26548) In addition, up to 0.0 GiB of shared memory is currently being used by the Ray object store.
# (PPO pid=26548) ---
# (PPO pid=26548) --- Tip: Use the `ray memory` command to list active objects in the cluster.
# (PPO pid=26548) --- To disable OOM exceptions, set RAY_DISABLE_MEMORY_MONITOR=1.
# (PPO pid=26548) ---
# (pid=19488) B:\Anaconda\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
# (pid=19488)   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# (pid=19488) B:\Anaconda\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
# (pid=19488)   "class": algorithms.Blowfish,
# (PPO pid=19488) 2022-12-13 00:11:59,996	INFO ppo.py:379 -- In multi-agent mode, policies will be optimized sequentially by the multi-GPU optimizer. Consider setting simple_optimizer=True if this doesn't work for you.
# (PPO pid=19488) 2022-12-13 00:11:59,998	INFO algorithm.py:457 -- Current log_level is ERROR. For more information, set 'log_level': 'INFO' / 'DEBUG' or use the -v and -vv flags.
# (pid=19344) B:\Anaconda\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
# (pid=19344)   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# (pid=5964) B:\Anaconda\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.4
# (pid=5964)   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# (pid=5964) B:\Anaconda\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
# (pid=5964)   "class": algorithms.Blowfish,
# (pid=19344) B:\Anaconda\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
# (pid=19344)   "class": algorithms.Blowfish,
# (PPO pid=19488) 2022-12-13 00:12:12,549	INFO trainable.py:164 -- Trainable.setup took 12.554 seconds. If your trainable is slow to initialize, consider setting reuse_actors=True to reduce actor creation overheads.
# (PPO pid=19488) 2022-12-13 00:12:12,550	WARNING util.py:66 -- Install gputil for GPU system monitoring.
# 2022-12-13 01:10:52,953	WARNING tune.py:705 -- Stop signal received (e.g. via SIGINT/Ctrl+C), ending Ray Tune run. This will try to checkpoint the experiment state one last time. Press CTRL+C (or send SIGINT/SIGKILL/SIGTERM) to skip.
# 2022-12-13 01:10:53,272	ERROR tune.py:773 -- Trials did not complete: [PPO_TradingEnv_408e835f, PPO_TradingEnv_4d0ed2cc, PPO_TradingEnv_59d1c2bb, PPO_TradingEnv_5be00eaa]
# 2022-12-13 01:10:53,273	INFO tune.py:777 -- Total run time: 3589.73 seconds (3588.33 seconds for the tuning loop).
# 2022-12-13 01:10:53,274	WARNING tune.py:783 -- Experiment has been interrupted, but the most recent state was saved. You can continue running this experiment by passing `resume=True` to `tune.run()`
# Time taken: 3589.83 seconds.
# Best config: {'env': 'TradingEnv', 'env_config': {'RMS_filename': 'D:\\Trading\\ACP\\ProjetFinance\\RMS_train.pickle', 'AIR_filename': 'D:\\Trading\\ACP\\ProjetFinance\\AIR_train.pickle', 'max_allowed_loss': 0.1, 'window_size': 30}, 'log_level': 'ERROR', 'framework': 'torch', 'ignore_worker_failures': True, 'num_workers': 2, 'num_gpus': 0, 'clip_rewards': True, 'lr': 3.411557990509073e-05, 'lr_schedule': [[0, 0.1], [100, 0.01], [1000, 0.001], [10000, 0.0001], [100000, 1e-05], [1000000, 1e-06], [10000000, 1e-07]], 'model': {'use_lstm': True, 'lstm_cell_size': 512}, 'gamma': 0.9465503483672058, 'observation_filter': 'MeanStdFilter', 'lambda': 0.10409330402664757, 'vf_share_layers': True, 'vf_loss_coeff': 0.7010002326205678, 'entropy_coeff': 0.03691156725999126, 'evaluation_interval': 1, 'evaluation_config': {'env_config': {'RMS_filename': 'D:\\Trading\\ACP\\ProjetFinance\\RMS_test.pickle', 'AIR_filename': 'D:\\Trading\\ACP\\ProjetFinance\\AIR_test.pickle', 'max_allowed_loss': 1.0, 'window_size': 30}, 'explore': False}}

# %%
window_size = 30
#1028
n_steps = 101
def get_optimal_batch_size(window_size=30, n_steps=101, batch_factor=4, stride=1):
    """
    lookback = 30          # Days of past data (also named window_size).
    batch_factor = 4       # batch_size = (sample_size - lookback - stride) // batch_factor
    stride = 1             # Time series shift into the future.
    """
    lookback = window_size
    sample_size = n_steps
    batch_size = ((sample_size - lookback - stride) // batch_factor)
    return batch_size

batch_size = get_optimal_batch_size(window_size=window_size, n_steps=n_steps, batch_factor=4)
batch_size
# Out:
# 17

# %%
 #(1029 days - 4 trading years)
memory_capacity = n_steps * 10
n_bins = 5             # Number of bins to partition the dataset evenly in order to evaluate class sparsity.
seed = 1337
commission = 0.001
save_path = 'agents/'

agent = DQNAgent(env1)

agent.train(batch_size=batch_size, 
            n_steps=n_steps, 
            n_episodes=1, 
            memory_capacity=memory_capacity, 
            save_path=save_path)
# Out:
# ====      AGENT ID: 26285cf4-fd3c-4a4f-9848-124eda32e3b7      ====
#   0%|          | 0/1 [00:00<?, ?it/s]
# FigureWidget({
#     'data': [{'name': 'Price',
#               'showlegend': False,
#               'type': 'candle…
# <div>                            <div id="fc587814-21e2-492c-aa4b-7e2f11370942" class="plotly-graph-div" style="height:800px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fc587814-21e2-492c-aa4b-7e2f11370942")) {                    Plotly.newPlot(                        "fc587814-21e2-492c-aa4b-7e2f11370942",                        [{"name":"Price","showlegend":false,"xaxis":"x","yaxis":"y","type":"candlestick","uid":"f683baa9-e10b-4f1a-9f80-e691394feb0c","close":[97.72879791259766,98.58650207519531,98.58650207519531,100.34134674072266,99.57237243652344,99.67095947265625,95.96410369873047,95.69792175292969,93.86421203613281,94.61347198486328,95.12611389160156,96.29930114746094,96.02325439453125,96.31901550292969,95.1754150390625,99.00056457519531,99.276611328125,99.1188735961914,99.37519836425781,99.67095947265625,98.48792266845703],"high":[98.586503198181,98.74424408886115,99.88784360172576,101.64268834678039,101.14975505001902,100.97230109552899,98.66537944532442,96.62463732280781,95.65848615548356,95.40215952804378,95.23455964577416,97.29502698256091,97.40346692601139,96.90067981251852,96.62463789965443,100.00615111855349,100.6568239552902,100.20332365307989,100.00615138383917,102.6285547538719,100.08501927894616],"low":[96.14155460938268,96.41760203816229,98.24145082224277,98.24145682595216,99