# %%
from main import add_custom_indicators
import yfinance as yf
nasdaq_tickers = ['TMUSR', 'AAPL', 'MSFT', 'AMZN', 'FB', 'GOOGL', 'GOOG', 'INTC', 'NVDA', 'ADBE',
               'PYPL', 'CSCO', 'NFLX', 'PEP', 'TSLA', 'CMCSA', 'AMGN', 'COST', 'TMUS', 'AVGO',
               'TXN', 'CHTR', 'QCOM', 'GILD', 'SBUX', 'INTU', 'VRTX', 'MDLZ', 'ISRG', 'FISV',
               'BKNG', 'ADP', '', 'ATVI', 'AMD', 'JD', 'MU', 'AMAT', 'ILMN', 'ADSK',
               'CSX', 'MELI', 'LRCX', 'ADI', 'ZM', 'BIIB', 'EA', 'KHC', 'WBA', 'LULU',
               'EBAY', 'MNST', 'DXCM', 'EXC', 'BIDU', 'XEL', 'WDAY', 'DOCU', 'SPLK', 'ORLY',
               'NXPI', 'CTSH', 'KLAC', 'SNPS', 'SGEN', 'ASML', 'IDXX', 'CSGP', 'CTAS', 'VRSK',
               'MAR', 'CDNS', 'PAYX', 'ALXN', 'MCHP', 'SIRI', 'ANSS', 'VRSN', 'FAST', 'BMRN',
               'XLNX', 'INCY','DLTR', 'SWKS', 'ALGN', 'CERN', 'CPRT', 'CTXS', 'TTWO', 'MXIM',
               'CDW', 'CHKP', 'WDC', 'ULTA', 'NTAP', 'FOXA', 'LBTYK']

# %%
data = yf.Ticker(nasdaq_tickers[9]).history(period='5y').drop(columns=['Dividends','Stock Splits'])

# %%
data = add_custom_indicators(data)
# Out:
# /Users/louisdelacour/opt/anaconda3/lib/python3.9/site-packages/ta/trend.py:780: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /Users/louisdelacour/opt/anaconda3/lib/python3.9/site-packages/ta/trend.py:785: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# /Users/louisdelacour/opt/anaconda3/lib/python3.9/site-packages/ta/trend.py:780: RuntimeWarning: invalid value encountered in double_scalars
#   dip[idx] = 100 * (self._dip[idx] / value)
# /Users/louisdelacour/opt/anaconda3/lib/python3.9/site-packages/ta/trend.py:785: RuntimeWarning: invalid value encountered in double_scalars
#   din[idx] = 100 * (self._din[idx] / value)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'volume'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/p1/t6dp7fjx39v2j8bnc1tv9bq80000gn/T/ipykernel_1398/415422006.py in <module>
# ----> 1 data = add_custom_indicators(data)
#
# ~/Documents/GitHub/ProjetFinance/main.py in add_custom_indicators(df)
#     201
#     202     # PVO
# --> 203     #df['pvo'] = ta.momentum.pvo(volume = df['Volume'], window_slow=26, window_fast=12, window_sign=9)
#     204     #df['pvo_signal'] = ta.momentum.pvo_signal(volume = df['Volume'], window_slow=26, window_fast=12, window_sign=9)
#     205     #df['pvo_histo'] = ta.momentum.pvo_hist(volume = df['Volume'], window_slow=26, window_fast=12, window_sign=9)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3503             if self.columns.nlevels > 1:
#    3504                 return self._getitem_multilevel(key)
# -> 3505             indexer = self.columns.get_loc(key)
#    3506             if is_integer(indexer):
#    3507                 indexer = [indexer]
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
# -> 3631                 raise KeyError(key) from err
#    3632             except TypeError:
#    3633                 # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'volume'

# %%
data
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2017-11-20 00:00:00-05:00  182.800003  183.429993  181.339996  182.339996
# 2017-11-21 00:00:00-05:00  183.750000  185.550003  182.839996  184.149994
# 2017-11-22 00:00:00-05:00  184.320007  184.500000  182.619995  182.899994
# 2017-11-24 00:00:00-05:00  182.960007  184.710007  182.960007  184.460007
# 2017-11-27 00:00:00-05:00  184.830002  185.839996  184.089996  185.000000
# ...                               ...         ...         ...         ...
# 2022-11-14 00:00:00-05:00  338.070007  345.109985  334.429993  340.369995
# 2022-11-15 00:00:00-05:00  348.410004  350.970001  342.559998  345.959991
# 2022-11-16 00:00:00-05:00  345.000000  345.019989  336.720001  338.410004
# 2022-11-17 00:00:00-05:00  331.739990  339.869995  329.350006  337.829987
# 2022-11-18 00:00:00-05:00  331.739990  344.589996  340.140015  340.250000
#
#                             Volume
# Date
# 2017-11-20 00:00:00-05:00  1118100
# 2017-11-21 00:00:00-05:00  2036500
# 2017-11-22 00:00:00-05:00  1546700
# 2017-11-24 00:00:00-05:00   663000
# 2017-11-27 00:00:00-05:00  1305100
# ...                            ...
# 2022-11-14 00:00:00-05:00  3464500
# 2022-11-15 00:00:00-05:00  2948600
# 2022-11-16 00:00:00-05:00  2123200
# 2022-11-17 00:00:00-05:00  2740400
# 2022-11-18 00:00:00-05:00   135229
#
# [1259 rows x 5 columns]

# %%
data.isna().sum()
# Out:
# Open        0
# High        0
# Low         0
# Close       0
# ema7        6
# ema30      29
# ema50      49
# ema100     99
# ema150    149
# ema200    199
# sma7        6
# sma30      29
# sma50      49
# sma100     99
# sma150    149
# sma200    199
# dtype: int64
